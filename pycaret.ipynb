# %%
import pandas as pd
df = pd.read_csv("dataset\ILPD\ilpd.csv")
df.head()
# Out:
#    age  gender    tb   db  alkphos  sgpt  sgot   tp  alb  ag_ratio  class
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3      0.90      1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2      0.74      1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3      0.89      1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4      1.00      1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4      0.40      1

# %%
from pycaret.classification import *
s = setup(df, target = 'class', session_id = 123)
# Out:
# <style type="text/css">
# #T_ae6ab_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ae6ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae6ab_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ae6ab_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae6ab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae6ab_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ae6ab_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ae6ab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae6ab_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ae6ab_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_ae6ab_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# functional API
best = compare_models()
# Out:
# <style type="text/css">
# #T_06f1e th {
#   text-align: left;
# }
# ...

# %%
best
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# functional API
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# functional API
pred_scores = predict_model(best)
